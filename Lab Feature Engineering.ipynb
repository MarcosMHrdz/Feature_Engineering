# %% [markdown]
# Ingeniería de laboratorio

# %%
import pandas as pd
# Leemos y exploramos los datos
df=pd.read_csv(r"C:\Users\marco\OneDrive\Desktop\ironhack\Laboratorios\Lab-50\learningSet.csv")
# Out:
# C:\Users\marco\AppData\Local\Temp\ipykernel_14548\3441963212.py:3: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv(r"C:\Users\marco\OneDrive\Desktop\ironhack\Laboratorios\Lab-50\learningSet.csv")

# %% [markdown]
# Aquí trabajaremos en la limpieza de algunas de las otras columnas del conjunto de datos utilizando las técnicas que hemos usado antes en las lecciones.
#
# Comprueba si hay valores nulos en las columnas numéricas.

# %%
numericals = df.select_dtypes(include=['int', 'float'])
categoricals = df.select_dtypes(exclude=['int', 'float'])

# %%
numericals
# Out:
#        ODATEDW  TCODE   DOB   AGE  NUMCHLD  INCOME  WEALTH1  HIT  MBCRAFT  \
# 0         8901      0  3712  60.0      NaN     NaN      NaN    0      NaN
# 1         9401      1  5202  46.0      1.0     6.0      9.0   16      0.0
# 2         9001      1     0   NaN      NaN     3.0      1.0    2      0.0
# 3         8701      0  2801  70.0      NaN     1.0      4.0    2      0.0
# 4         8601      0  2001  78.0      1.0     3.0      2.0   60      1.0
# ...        ...    ...   ...   ...      ...     ...      ...  ...      ...
# 95407     9601      1     0   NaN      NaN     NaN      NaN    0      NaN
# 95408     9601      1  5001  48.0      1.0     7.0      9.0    1      0.0
# 95409     9501      1  3801  60.0      NaN     NaN      NaN    0      NaN
# 95410     8601      0  4005  58.0      NaN     7.0      NaN    0      NaN
# 95411     8801      2  1801  80.0      NaN     5.0      8.0    3      0.0
#
#        MBGARDEN  ...  FISTDATE  NEXTDATE  TIMELAG    AVGGIFT  CONTROLN  \
# ...

# %%
conteo_nulos_por_columna = numericals.isnull().sum()

# %%
conteo_nulos_por_columna
# Out:
# ODATEDW         0
# TCODE           0
# DOB             0
# AGE         23665
# NUMCHLD     83026
#             ...
# TARGET_B        0
# TARGET_D        0
# HPHONE_D        0
# RFA_2F          0
# CLUSTER2      132
# Length: 407, dtype: int64

# %%
numericals.columns.tolist()
# Out:
# ['ODATEDW',
#  'TCODE',
#  'DOB',
#  'AGE',
#  'NUMCHLD',
#  'INCOME',
#  'WEALTH1',
#  'HIT',
#  'MBCRAFT',
#  'MBGARDEN',
#  'MBBOOKS',
#  'MBCOLECT',
#  'MAGFAML',
#  'MAGFEM',
#  'MAGMALE',
#  'PUBGARDN',
#  'PUBCULIN',
#  'PUBHLTH',
#  'PUBDOITY',
#  'PUBNEWFN',
#  'PUBPHOTO',
#  'PUBOPP',
#  'MALEMILI',
#  'MALEVET',
#  'VIETVETS',
#  'WWIIVETS',
#  'LOCALGOV',
#  'STATEGOV',
#  'FEDGOV',
#  'WEALTH2',
#  'POP901',
#  'POP902',
#  'POP903',
#  'POP90C1',
#  'POP90C2',
#  'POP90C3',
#  'POP90C4',
#  'POP90C5',
#  'ETH1',
#  'ETH2',
#  'ETH3',
#  'ETH4',
#  'ETH5',
#  'ETH6',
#  'ETH7',
#  'ETH8',
#  'ETH9',
#  'ETH10',
#  'ETH11',
#  'ETH12',
#  'ETH13',
#  'ETH14',
#  'ETH15',
#  'ETH16',
#  'AGE901',
#  'AGE902',
#  'AGE903',
#  'AGE904',
#  'AGE905',
#  'AGE906',
#  'AGE907',
#  'CHIL1',
#  'CHIL2',
#  'CHIL3',
#  'AGEC1',
#  'AGEC2',
#  'AGEC3',
#  'AGEC4',
#  'AGEC5',
#  'AGEC6',
#  'AGEC7',
#  'CHILC1',
#  'CHILC2',
#  'CHILC3',
#  'CHILC4',
#  'CHILC5',
#  'HHAGE1',
# ...

# %%
tipos=numericals[["WEALTH1", "ADI", "DMA","MSA"]].dtypes
tipos
# Out:
# WEALTH1    float64
# ADI        float64
# DMA        float64
# MSA        float64
# dtype: object

# %%
numericals["WEALTH1"].isnull().sum()
# Out:
# 44732

# %%
numericals["WEALTH1"].mean()
# Out:
# 5.345698500394633

# %%
for column in numericals:
    # Calcular la media de la columna actual
    media = numericals[column].mean()
    
    # Llenar los NaN en la columna actual con la media calculada
    numericals[column] = numericals[column].fillna(media)

# Mostrar el DataFrame después de llenar los NaN con la media
print(numericals)
# Out:
#        ODATEDW  TCODE   DOB        AGE   NUMCHLD    INCOME   WEALTH1  HIT  \
# 0         8901      0  3712  60.000000  1.527773  3.886248  5.345699    0
# 1         9401      1  5202  46.000000  1.000000  6.000000  9.000000   16
# 2         9001      1     0  61.611649  1.527773  3.000000  1.000000    2
# 3         8701      0  2801  70.000000  1.527773  1.000000  4.000000    2
# 4         8601      0  2001  78.000000  1.000000  3.000000  2.000000   60
# ...        ...    ...   ...        ...       ...       ...       ...  ...
# 95407     9601      1     0  61.611649  1.527773  3.886248  5.345699    0
# 95408     9601      1  5001  48.000000  1.000000  7.000000  9.000000    1
# 95409     9501      1  3801  60.000000  1.527773  3.886248  5.345699    0
# 95410     8601      0  4005  58.000000  1.527773  7.000000  5.345699    0
# 95411     8801      2  1801  80.000000  1.527773  5.000000  8.000000    3
#
#         MBCRAFT  MBGARDEN  ...  FISTDATE     NEXTDATE    TIMELAG    AVGGIFT  \
# ...

# %% [markdown]
# Use appropriate EDA technique where ever necessary.

# %%
numericals.shape
# Out:
# (95412, 407)

# %%
numericals.describe()
# Out:
#             ODATEDW         TCODE           DOB           AGE       NUMCHLD  \
# count  95412.000000  95412.000000  95412.000000  95412.000000  95412.000000
# mean    9141.363256     54.223117   2723.602933     61.611649      1.527773
# std      343.454752    953.844476   2132.241295     14.450539      0.290702
# min     8306.000000      0.000000      0.000000      1.000000      1.000000
# 25%     8801.000000      0.000000    201.000000     52.000000      1.527773
# 50%     9201.000000      1.000000   2610.000000     61.611649      1.527773
# 75%     9501.000000      2.000000   4601.000000     71.000000      1.527773
# max     9701.000000  72002.000000   9710.000000     98.000000      7.000000
#
#              INCOME       WEALTH1           HIT       MBCRAFT      MBGARDEN  \
# count  95412.000000  95412.000000  95412.000000  95412.000000  95412.000000
# mean       3.886248      5.345699      3.321438      0.152075      0.059166
# ...

# %%
for columna in numericals:
    plt.figure(figsize=(8, 6))
    sns.histplot(numericals[columna], bins=30, kde=True)
    plt.title(f'Distribución de la columna {columna}')
    plt.xlabel('Valores')
    plt.ylabel('Frecuencia')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[33], line 3
#       1 for columna in numericals:
#       2     plt.figure(figsize=(8, 6))
# ----> 3     sns.histplot(numericals[columna], bins=30, kde=True)
#       4     plt.title(f'Distribución de la columna {columna}')
#       5     plt.xlabel('Valores')
#
# File c:\Users\anasa\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\distributions.py:1416, in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1405 estimate_kws = dict(
#    1406     stat=stat,
#    1407     bins=bins,
#    (...)
#    1411     cumulative=cumulative,
#    1412 )
#    1414 if p.univariate:
# ...
